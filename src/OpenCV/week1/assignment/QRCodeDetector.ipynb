# %%
# Import modules
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

DATA_PATH = "/Users/admin/Iqbal/Study/OpenCV/LearnOpenCV/src/res/opencv-courses/"

# %%
import matplotlib

matplotlib.rcParams['figure.figsize'] = (10.0, 10.0)

# %%
# Image Path
imgPath = DATA_PATH + "images/IDCard-Satya.png"

# Read image
img = cv2.imread(imgPath)

# %%
# Create a QRCodeDetector Object
# Variable name should be qrDecoder
qrDecoder = cv2.QRCodeDetector()

# Detect QR Code in the Image
# Output should be stored in
# opencvData, bbox, rectifiedImage
# in the same order

opencvData, bbox, rectifiedImage = qrDecoder.detectAndDecode(img)
# Check if a QR Code has been detected
if opencvData != None:
    print("QR Code Detected")
    plt.imshow(img[..., ::-1])
else:
    print("QR Code NOT Detected")
# Out:
# QR Code Detected

# %%
bbox1 = bbox[0]
n = len(bbox1)

# Draw the bounding box
for j in range(n):
    cv2.line(img, tuple(bbox1[j]), tuple(bbox1[(j + 1) % n]), (255, 0, 0), 3)
plt.imshow(img[..., ::-1])
# Out:
# /var/folders/nj/yfdjzlhj4ng_ndb0wp1g5rcm0000gn/T/ipykernel_51929/407698762.py:6: DeprecationWarning: an integer is required (got type numpy.float32).  Implicit conversion to integers using __int__ is deprecated, and may be removed in a future version of Python.
#   cv2.line(img, tuple(bbox1[j]), tuple(bbox1[(j + 1) % n]), (255, 0, 0), 3)

# %%
# Since we have already detected and decoded the QR Code
# using qrDecoder.detectAndDecode, we will directly
# use the decoded text we obtained at that step (opencvdata)

print("QR Code Detected!")
cv2.putText(img,opencvData,(170,130),cv2.FONT_HERSHEY_SIMPLEX,0.35,(10,10,10),1,cv2.LINE_AA)
print(opencvData)
# Out:
# QR Code Detected!
# Name: Satya, ID: 1234

# %%
# Write the result image
resultImagePath = "QRCode-Output.png"
cv2.imwrite(resultImagePath,img)
# Out:
# True

# %%
# Display the result image
plt.imshow(img)

# Notice anything wrong?

# %%
# OpenCV uses BGR whereas Matplotlib uses RGB format
# So convert the BGR image to RGB image
# And display the correct image

plt.imshow(img[:, :, ::-1])

# %%
a = [[1, 2, 4], [1, 4, 9]]
print(a[0][0])
print(tuple(a[0, 1]))
# Out:
# 1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/nj/yfdjzlhj4ng_ndb0wp1g5rcm0000gn/T/ipykernel_51929/1112148329.py in <module>
#       1 a = [[1, 2, 4], [1, 4, 9]]
#       2 print(a[0][0])
# ----> 3 print(tuple(a[0, 1]))
#
# TypeError: list indices must be integers or slices, not tuple
